# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
df = pd.read_csv('datasets/ipl_games.csv')
df
# Out:
#     game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0      0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 1      1     Dubai     DC   KXIP        KXIP         Field           DC
# 2      2     Dubai    SRH    RCB         SRH         Field          RCB
# 3      3   Sharjah     RR    CSK          RR         Field           RR
# 4      4  AbuDhabi    KKR     MI         KKR         Field           MI
# 5      5     Dubai   KXIP    RCB         RCB         Field         KXIP
# 6      6     Dubai    CSK     DC         CSK         Field           DC
# 7      7  AbuDhabi    KKR    SRH         SRH           Bat          KKR
# 8      8   Sharjah     RR   KXIP          RR         Field           RR
# 9      9     Dubai    RCB     MI          MI         Field          RCB
# 10    10  AbuDhabi     DC    SRH          DC         Field          SRH
# 11    11     Dubai     RR    KKR          RR         Field          KKR
# ...

# %%
df.head()
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0     0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 1     1     Dubai     DC   KXIP        KXIP         Field           DC
# 2     2     Dubai    SRH    RCB         SRH         Field          RCB
# 3     3   Sharjah     RR    CSK          RR         Field           RR
# 4     4  AbuDhabi    KKR     MI         KKR         Field           MI
#
#    winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 0           2        51        85        26        2        3        4
# 1           1        23        70        64        3        2        3
# 2           2        48        79        26        0        2        3
# 3           1        54       112        50        1        3        2
# 4           2        33        69        44        2        4        3
#
#    runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# ...

# %%
df.head(1)
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0     0  AbuDhabi     MI    CSK         CSK         Field          CSK
#
#    winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 0           2        51        85        26        2        3        4
#
#    runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# 0        37        84        45        2        1        2

# %%
df.tail(1)
# Out:
#     game  stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 55    55  Sharjah    SRH     MI         SRH         Field          SRH
#
#     winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 55           1        56        58         7        0        0        0
#
#     runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# 55        48        61        40        2        3        3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game           56 non-null     int64
#  1   stadium        56 non-null     object
#  2   team_1         56 non-null     object
#  3   team_2         56 non-null     object
#  4   toss_winner    56 non-null     object
#  5   toss_decision  56 non-null     object
#  6   match_winner   56 non-null     object
#  7   winner_num     56 non-null     int64
#  8   runs_pp1       56 non-null     int64
#  9   runs_mo1       56 non-null     int64
#  10  runs_do1       56 non-null     int64
#  11  wkt_pp1        56 non-null     int64
#  12  wkt_mo1        56 non-null     int64
#  13  wkt_do1        56 non-null     int64
#  14  runs_pp2       56 non-null     int64
#  15  runs_mo2       56 non-null     int64
#  16  runs_do2       56 non-null     int64
#  17  wkt_pp2        56 non-null     int64
# ...

# %%
df.corr()
# Out:
#                 game  winner_num  runs_pp1  runs_mo1  runs_do1   wkt_pp1  \
# game        1.000000   -0.067436  0.061718 -0.138386 -0.355718 -0.015621
# winner_num -0.067436    1.000000 -0.438432 -0.478445 -0.169721  0.297753
# runs_pp1    0.061718   -0.438432  1.000000  0.496636  0.115381 -0.602768
# runs_mo1   -0.138386   -0.478445  0.496636  1.000000  0.127336 -0.392977
# runs_do1   -0.355718   -0.169721  0.115381  0.127336  1.000000 -0.021868
# wkt_pp1    -0.015621    0.297753 -0.602768 -0.392977 -0.021868  1.000000
# wkt_mo1    -0.033487    0.241188 -0.270861 -0.273994 -0.012228  0.124845
# wkt_do1    -0.266055    0.425828 -0.180633 -0.000057 -0.116331  0.008238
# runs_pp2    0.153974    0.057536  0.248816  0.233047  0.009153 -0.060530
# runs_mo2   -0.330144    0.143656  0.083218  0.259784  0.169934 -0.006043
# runs_do2   -0.305185   -0.121479  0.128036  0.268098  0.046292 -0.067797
# wkt_pp2    -0.050526   -0.243709  0.177781  0.094057  0.068731 -0.214690
# ...

# %%
print(df.columns)
# Out:
# Index(['game', 'stadium', 'team_1', 'team_2', 'toss_winner', 'toss_decision',
#        'match_winner', 'winner_num', 'runs_pp1', 'runs_mo1', 'runs_do1',
#        'wkt_pp1', 'wkt_mo1', 'wkt_do1', 'runs_pp2', 'runs_mo2', 'runs_do2',
#        'wkt_pp2', 'wkt_mo2', 'wkt_do2'],
#       dtype='object')

# %%
df['team_1'].unique()
# Out:
# array(['MI', 'DC', 'SRH', 'RR', 'KKR', 'KXIP', 'CSK', 'RCB'], dtype=object)

# %%
print(len(df[df['winner_num'] == 2]))
df[df['winner_num'] == 2]
# Out:
# 27
#     game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0      0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 2      2     Dubai    SRH    RCB         SRH         Field          RCB
# 4      4  AbuDhabi    KKR     MI         KKR         Field           MI
# 6      6     Dubai    CSK     DC         CSK         Field           DC
# 10    10  AbuDhabi     DC    SRH          DC         Field          SRH
# 11    11     Dubai     RR    KKR          RR         Field          KKR
# 12    12     Dubai   KXIP     MI        KXIP         Field           MI
# 13    13     Dubai    CSK    SRH         SRH           Bat          SRH
# 17    17     Dubai   KXIP    CSK        KXIP           Bat          CSK
# 18    18     Dubai    RCB     DC          DC           Bat           DC
# 22    22   Sharjah     RR     DC          RR         Field           DC
# 23    23  AbuDhabi   KXIP    KKR         KKR           Bat          KKR
# ...

# %%
df[df['team_1'] == 'MI'].append(df[df['team_2'] == 'MI']).sort_index()
# Out:
#     game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0      0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 4      4  AbuDhabi    KKR     MI         KKR         Field           MI
# 9      9     Dubai    RCB     MI          MI         Field          RCB
# 12    12     Dubai   KXIP     MI        KXIP         Field           MI
# 16    16   Sharjah     MI    SRH          MI           Bat           MI
# 19    19  AbuDhabi     MI     RR          MI           Bat           MI
# 26    26  AbuDhabi     MI     DC          DC           Bat           MI
# 31    31  AbuDhabi     MI    KKR         KKR           Bat           MI
# 35    35     Dubai     MI   KXIP          MI           Bat         KXIP
# 40    40   Sharjah    CSK     MI          MI         Field           MI
# 44    44  AbuDhabi     RR     MI          MI           Bat           RR
# 47    47  AbuDhabi     MI    RCB          MI         Field          RCB
# ...

# %%
grps = df.groupby('stadium')
print(grps.ngroups)
print(grps.groups)
# Out:
# 3
# {'AbuDhabi': Int64Index([0, 4, 7, 10, 14, 19, 20, 23, 26, 31, 34, 36, 38, 41, 44, 47, 49,
#             52, 54],
#            dtype='int64'), 'Dubai': Int64Index([ 1,  2,  5,  6,  9, 11, 12, 13, 17, 18, 21, 24, 25, 28, 29, 32, 35,
#             37, 39, 42, 43, 46, 48, 50, 53],
#            dtype='int64'), 'Sharjah': Int64Index([3, 8, 15, 16, 22, 27, 30, 33, 40, 45, 51, 55], dtype='int64')}

# %%
df.groupby('team_1').get_group('CSK').append(df.groupby('team_2').get_group('CSK'))
# Out:
#     game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 6      6     Dubai    CSK     DC         CSK         Field           DC
# 13    13     Dubai    CSK    SRH         SRH           Bat          SRH
# 24    24     Dubai    CSK    RCB         RCB           Bat          RCB
# 36    36  AbuDhabi    CSK     RR         CSK           Bat           RR
# 40    40   Sharjah    CSK     MI          MI         Field           MI
# 48    48     Dubai    CSK    KKR         CSK         Field          CSK
# 52    52  AbuDhabi    CSK   KXIP         CSK         Field          CSK
# 0      0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 3      3   Sharjah     RR    CSK          RR         Field           RR
# 17    17     Dubai   KXIP    CSK        KXIP           Bat          CSK
# 20    20  AbuDhabi    KKR    CSK         KKR           Bat          KKR
# 28    28     Dubai    SRH    CSK         CSK           Bat          CSK
# ...

# %%
print(df['match_winner'].mode())
print('------------------------------------------')

dict = df.groupby('match_winner').groups
for x in dict:
    print(x, len(dict[x]))
print('------------------------------------------')

dict
# Out:
# 0     DC
# 1     MI
# 2    RCB
# dtype: object
# ------------------------------------------
# CSK 6
# DC 8
# KKR 7
# KXIP 6
# MI 8
# RCB 8
# RR 6
# SRH 7
# ------------------------------------------
# {'CSK': Int64Index([0, 17, 28, 43, 48, 52], dtype='int64'),
#  'DC': Int64Index([1, 6, 15, 18, 22, 29, 33, 54], dtype='int64'),
#  'KKR': Int64Index([7, 11, 20, 23, 34, 41, 53], dtype='int64'),
#  'KXIP': Int64Index([5, 30, 35, 37, 42, 45], dtype='int64'),
#  'MI': Int64Index([4, 12, 16, 19, 26, 31, 40, 50], dtype='int64'),
#  'RCB': Int64Index([2, 9, 14, 24, 27, 32, 38, 47], dtype='int64'),
#  'RR': Int64Index([3, 8, 25, 36, 44, 49], dtype='int64'),
#  'SRH': Int64Index([10, 13, 21, 39, 46, 51, 55], dtype='int64')}

# %%
df[df['team_1'] == 'MI'].append(df[df['team_2'] == 'MI'])['winner_num'].plot(kind='hist')
plt.show()

# %%
df.plot()
plt.show()

# %%
df[['runs_pp1', 'runs_pp2']].plot()
plt.show()

# %%
df[['runs_mo1', 'runs_mo2']].plot(kind='bar')
plt.show()

# %%
df.plot(kind='scatter', x='game', y='runs_pp1')
plt.show()

# %%
df[['runs_pp1', 'runs_mo1', 'runs_do1']].plot(kind='area')
plt.show()

# %%
df.loc[[1,4]]
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 1     1     Dubai     DC   KXIP        KXIP         Field           DC
# 4     4  AbuDhabi    KKR     MI         KKR         Field           MI
#
#    winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 1           1        23        70        64        3        2        3
# 4           2        33        69        44        2        4        3
#
#    runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# 1        35        63        59        3        2        3
# 4        59        89        47        1        2        2

# %%
df.loc[1:4]
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 1     1     Dubai     DC   KXIP        KXIP         Field           DC
# 2     2     Dubai    SRH    RCB         SRH         Field          RCB
# 3     3   Sharjah     RR    CSK          RR         Field           RR
# 4     4  AbuDhabi    KKR     MI         KKR         Field           MI
#
#    winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 1           1        23        70        64        3        2        3
# 2           2        48        79        26        0        2        3
# 3           1        54       112        50        1        3        2
# 4           2        33        69        44        2        4        3
#
#    runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# 1        35        63        59        3        2        3
# 2        53        71        39        1        4        6
# 3        53        85        62        0        5        2
# ...

# %%
df.loc[0:5][['team_1', 'team_2']]
# Out:
#   team_1 team_2
# 0     MI    CSK
# 1     DC   KXIP
# 2    SRH    RCB
# 3     RR    CSK
# 4    KKR     MI
# 5   KXIP    RCB

# %%
data_dict = df.loc[0:5][['team_1', 'team_2', 'toss_winner', 'match_winner']].to_dict()
data_dict
# Out:
# {'team_1': {0: 'MI', 1: 'DC', 2: 'SRH', 3: 'RR', 4: 'KKR', 5: 'KXIP'},
#  'team_2': {0: 'CSK', 1: 'KXIP', 2: 'RCB', 3: 'CSK', 4: 'MI', 5: 'RCB'},
#  'toss_winner': {0: 'CSK', 1: 'KXIP', 2: 'SRH', 3: 'RR', 4: 'KKR', 5: 'RCB'},
#  'match_winner': {0: 'CSK', 1: 'DC', 2: 'RCB', 3: 'RR', 4: 'MI', 5: 'KXIP'}}

# %%
x = ["team_1 total","team_2 total"]
y = [df['team_1 total'].mean(), df['team_2 total'].mean()]

plt.bar(x,y)
plt.title('Average Scores')
plt.xlabel('teams')
plt.ylabel('avg scores')

# %%
df['team_1 total'] = df['runs_pp1'] + df['runs_mo1'] + df['runs_do1']
df['team_2 total'] = df['runs_pp2'] + df['runs_mo2'] + df['runs_do2']

df.head(5)
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0     0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 1     1     Dubai     DC   KXIP        KXIP         Field           DC
# 2     2     Dubai    SRH    RCB         SRH         Field          RCB
# 3     3   Sharjah     RR    CSK          RR         Field           RR
# 4     4  AbuDhabi    KKR     MI         KKR         Field           MI
#
#    winner_num  runs_pp1  runs_mo1  ...  wkt_mo1  wkt_do1  runs_pp2  runs_mo2  \
# 0           2        51        85  ...        3        4        37        84
# 1           1        23        70  ...        2        3        35        63
# 2           2        48        79  ...        2        3        53        71
# 3           1        54       112  ...        3        2        53        85
# 4           2        33        69  ...        4        3        59        89
#
#    runs_do2  wkt_pp2  wkt_mo2  wkt_do2  team_1 total  team_2 total
# ...

# %%
print(df['runs_pp1'].mean())
print(df['runs_mo1'].mean())
print(df['runs_do1'].mean())
print(df['team_1 total'].mean())
print(df['team_2 total'].mean())
# Out:
# 46.107142857142854
# 77.35714285714286
# 38.55357142857143
# 162.01785714285714
# 160.82142857142858
