# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.__version__
# Out:
# '1.0.5'

# %%
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

mydf = pd.DataFrame(mydataset)
print(mydf)
mydf
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
a = [1, 7, 2]

myseries = pd.Series(a)
print(myseries.dtype)
print(myseries)
print('------------------------------------')

b = [1, True, 7, "asdf"]
myseries = pd.Series(b)
print(myseries.dtype)
print(myseries)
# Out:
# int64
# 0    1
# 1    7
# 2    2
# dtype: int64
# ------------------------------------
# object
# 0       1
# 1    True
# 2       7
# 3    asdf
# dtype: object

# %%
df = pd.read_csv('datasets/ipl_games.csv')
df
# Out:
#     game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0      0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 1      1     Dubai     DC   KXIP        KXIP         Field           DC
# 2      2     Dubai    SRH    RCB         SRH         Field          RCB
# 3      3   Sharjah     RR    CSK          RR         Field           RR
# 4      4  AbuDhabi    KKR     MI         KKR         Field           MI
# 5      5     Dubai   KXIP    RCB         RCB         Field         KXIP
# 6      6     Dubai    CSK     DC         CSK         Field           DC
# 7      7  AbuDhabi    KKR    SRH         SRH           Bat          KKR
# 8      8   Sharjah     RR   KXIP          RR         Field           RR
# 9      9     Dubai    RCB     MI          MI         Field          RCB
# 10    10  AbuDhabi     DC    SRH          DC         Field          SRH
# 11    11     Dubai     RR    KKR          RR         Field          KKR
# ...

# %%
df.head()
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0     0  AbuDhabi     MI    CSK         CSK         Field          CSK
# 1     1     Dubai     DC   KXIP        KXIP         Field           DC
# 2     2     Dubai    SRH    RCB         SRH         Field          RCB
# 3     3   Sharjah     RR    CSK          RR         Field           RR
# 4     4  AbuDhabi    KKR     MI         KKR         Field           MI
#
#    winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 0           2        51        85        26        2        3        4
# 1           1        23        70        64        3        2        3
# 2           2        48        79        26        0        2        3
# 3           1        54       112        50        1        3        2
# 4           2        33        69        44        2        4        3
#
#    runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# ...

# %%
df.head(1)
# Out:
#    game   stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 0     0  AbuDhabi     MI    CSK         CSK         Field          CSK
#
#    winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 0           2        51        85        26        2        3        4
#
#    runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# 0        37        84        45        2        1        2

# %%
df.tail(1)
# Out:
#     game  stadium team_1 team_2 toss_winner toss_decision match_winner  \
# 55    55  Sharjah    SRH     MI         SRH         Field          SRH
#
#     winner_num  runs_pp1  runs_mo1  runs_do1  wkt_pp1  wkt_mo1  wkt_do1  \
# 55           1        56        58         7        0        0        0
#
#     runs_pp2  runs_mo2  runs_do2  wkt_pp2  wkt_mo2  wkt_do2
# 55        48        61        40        2        3        3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   game           56 non-null     int64
#  1   stadium        56 non-null     object
#  2   team_1         56 non-null     object
#  3   team_2         56 non-null     object
#  4   toss_winner    56 non-null     object
#  5   toss_decision  56 non-null     object
#  6   match_winner   56 non-null     object
#  7   winner_num     56 non-null     int64
#  8   runs_pp1       56 non-null     int64
#  9   runs_mo1       56 non-null     int64
#  10  runs_do1       56 non-null     int64
#  11  wkt_pp1        56 non-null     int64
#  12  wkt_mo1        56 non-null     int64
#  13  wkt_do1        56 non-null     int64
#  14  runs_pp2       56 non-null     int64
#  15  runs_mo2       56 non-null     int64
#  16  runs_do2       56 non-null     int64
#  17  wkt_pp2        56 non-null     int64
# ...

# %%
df.corr()
# Out:
#                 game  winner_num  runs_pp1  runs_mo1  runs_do1   wkt_pp1  \
# game        1.000000   -0.067436  0.061718 -0.138386 -0.355718 -0.015621
# winner_num -0.067436    1.000000 -0.438432 -0.478445 -0.169721  0.297753
# runs_pp1    0.061718   -0.438432  1.000000  0.496636  0.115381 -0.602768
# runs_mo1   -0.138386   -0.478445  0.496636  1.000000  0.127336 -0.392977
# runs_do1   -0.355718   -0.169721  0.115381  0.127336  1.000000 -0.021868
# wkt_pp1    -0.015621    0.297753 -0.602768 -0.392977 -0.021868  1.000000
# wkt_mo1    -0.033487    0.241188 -0.270861 -0.273994 -0.012228  0.124845
# wkt_do1    -0.266055    0.425828 -0.180633 -0.000057 -0.116331  0.008238
# runs_pp2    0.153974    0.057536  0.248816  0.233047  0.009153 -0.060530
# runs_mo2   -0.330144    0.143656  0.083218  0.259784  0.169934 -0.006043
# runs_do2   -0.305185   -0.121479  0.128036  0.268098  0.046292 -0.067797
# wkt_pp2    -0.050526   -0.243709  0.177781  0.094057  0.068731 -0.214690
# ...

# %%
df.plot()
plt.show()
